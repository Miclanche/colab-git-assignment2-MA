# %% [markdown]
# <a href="https://colab.research.google.com/github/Miclanche/colab-git-assignment2-MA/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lesson 4 Assignment**
# ### **Data Processing - Python Development and Pandas**
#
# **Copy each task (including'Your code here:') to a different cell and complete the codes for each task. Add  your own comments where necessary**
#
# Remember to push your changes to github and submit a PDF copy of your completed notebook with the outputs.

# %%
# Python and Pandas Assessment Notebook

import pandas as pd
import numpy as np
from functools import reduce

# %%
# Task 1: Create a DataFrame using Pandas
# Create a DataFrame with the following data:
# Name: Alice, Bob, Charlie, David
# Age: 25, 30, 35, 28
# City: New York, San Francisco, Los Angeles, Chicago

data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, 30, 35, 28],
    "City": ["New York", "San Francisco", "Los Angeles", "Chicago"]
}

df = pd.DataFrame(data)

print("Task 1: DataFrame created:")
print(df)
print(df.dtypes)  # verify data types
# Out:
# Task 1: DataFrame created:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
# Task 2: Row and Column Manipulation
# Drop the 'City' column from the DataFrame created in Task 1
df_no_city = df.drop(columns=["City"])

print("\nTask 2: DataFrame after dropping 'City':")
print(df_no_city)
# Out:
# Task 2: DataFrame after dropping 'City':
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   28

# %%
# Task 3: Handling Null Values

# Create a new DataFrame with some null values and fill them
df_null = pd.DataFrame({
    "Mic": [1, None, 3],
    "Ken": [None, 5, None],
    "Ket": ["x", None, "z"]
})

print("\nTask 3: DataFrame with nulls:")
print(df_null)

# Fill numeric nulls with 0, string nulls with "Unknown"
df_filled = df_null.copy()
df_filled["Mic"] = df_filled["Mic"].fillna(0)
df_filled["Ken"] = df_filled["Ken"].fillna(0)
df_filled["Ket"] = df_filled["Ket"].fillna("Unknown")

print("\nTask 3: DataFrame after filling nulls:")
print(df_filled)
# Out:
# Task 3: DataFrame with nulls:
#    Mic  Ken   Ket
# 0  1.0  NaN     x
# 1  NaN  5.0  None
# 2  3.0  NaN     z
#
# Task 3: DataFrame after filling nulls:
#    Mic  Ken      Ket
# 0  1.0  0.0        x
# 1  0.0  5.0  Unknown
# 2  3.0  0.0        z

# %%
# Task 4: GroupBy and Describe
# Using the following DataFrame, group by 'Category' and describe the 'Value' column

df_group = pd.DataFrame({
    'Category': ['A', 'B', 'A', 'B', 'A', 'C'],
    'Value': [10, 20, 15, 25, 30, 35]
})

grouped_stats = df_group.groupby("Category")["Value"].describe()

print("\nTask 4: GroupBy describe results:")
print(grouped_stats)
# Out:
# Task 4: GroupBy describe results:
#           count       mean        std   min    25%   50%    75%   max
# Category
# A           3.0  18.333333  10.408330  10.0  12.50  15.0  22.50  30.0
# B           2.0  22.500000   3.535534  20.0  21.25  22.5  23.75  25.0
# C           1.0  35.000000        NaN  35.0  35.00  35.0  35.00  35.0

# %%
# Task 5: Concatenation and Merging
# Concatenate two DataFrames vertically and merge them horizontally

df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})
df3 = pd.DataFrame({'C': [9, 10], 'D': [11, 12]})

df_concat = pd.concat([df2, df3], axis=0)

print("\nTask 5: Concatenated DataFrame:")
print(df_concat)

# Merge horizontally with df1 (reset index to align rows)
df_merged = pd.concat([df_concat.reset_index(drop=True), df1], axis=1)

print("\nTask 5: Merged DataFrame:")
print(df_merged)
# Out:
# Task 5: Concatenated DataFrame:
#      A    B     C     D
# 0  5.0  7.0   NaN   NaN
# 1  6.0  8.0   NaN   NaN
# 0  NaN  NaN   9.0  11.0
# 1  NaN  NaN  10.0  12.0
#
# Task 5: Merged DataFrame:
#      A    B     C     D    A    B
# 0  5.0  7.0   NaN   NaN  1.0  3.0
# 1  6.0  8.0   NaN   NaN  2.0  4.0
# 2  NaN  NaN   9.0  11.0  NaN  NaN
# 3  NaN  NaN  10.0  12.0  NaN  NaN

# %%
# Task 6: Tuples and Sets
# Create a tuple of fruits and a set of numbers.

fruits = ("Mango", "banana", "Pie")
numbers_set = {1, 2, 3, 4, 5}

print("\nTask 6: Tuple:", fruits)
print("Task 6: Set:", numbers_set)

# Attempt to add elements
try:
    fruits.append("Pineaple")
except Exception as e:
    print("\nTuples are immutable, cannot add elements:", e)

numbers_set.add(6)
print("Set after adding element:", numbers_set)
# Out:
# Task 6: Tuple: ('Mango', 'banana', 'Pie')
# Task 6: Set: {1, 2, 3, 4, 5}
#
# Tuples are immutable, cannot add elements: 'tuple' object has no attribute 'append'
# Set after adding element: {1, 2, 3, 4, 5, 6}

# %%
# Task 7: Dictionaries
# Create a dictionary of student names and their scores.

students = {"Mic": 95, "Ken": 90, "Ket": 78}

# Update score
students["Mic"] = 90

# Add new student
students["Ana"] = 85

print("\nTask 7: Updated dictionary:")
print(students)
# Out:
# Task 7: Updated dictionary:
# {'Mic': 90, 'Ken': 90, 'Ket': 78, 'Ana': 85}

# %%
# Task 8: Functions and Lambda
# Create a function to calculate the square of a number.
# Then, use a lambda function to do the same.

def square(x):
    return x * x

square_lambda = lambda x: x * x

print("\nTask 8:")
print("Function square(8):", square(8))
print("Lambda square(11):", square_lambda(11))
# Out:
# Task 8:
# Function square(8): 64
# Lambda square(11): 121

# %%
# Task 9: Iterators and Generators
# Create an iterator for the first 5 even numbers.
# Then, create a generator for the same.

class EvenIterator:
    def __init__(self, limit=5):
        self.limit = limit
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count < self.limit:
            value = self.count * 2
            self.count += 1
            return value
        else:
            raise StopIteration

print("\nTask 9: Iterator output:")
for num in EvenIterator():
    print(num)

# Generator function
def even_generator(limit=5):
    for i in range(limit):
        yield i * 2

print("\nTask 9: Generator output:")
for num in even_generator():
    print(num)
# Out:
# Task 9: Iterator output:
# 0
# 2
# 4
# 6
# 8
#
# Task 9: Generator output:
# 0
# 2
# 4
# 6
# 8

# %%
# Task 10: Map, Reduce, and Filter

numbers = [1, 2, 3, 4, 5]

# Use map to square all numbers in a list.
squared = list(map(lambda x: x * x, numbers))

# Use reduce to find the product of all numbers in a list.
product = reduce(lambda x, y: x * y, numbers)


# Use filter to get only even numbers from a list.
evens = list(filter(lambda x: x % 2 == 0, numbers))

print("\nTask 10:")
print("Squared:", squared)
print("Product:", product)
print("Even numbers:", evens)
# Out:
# Task 10:
# Squared: [1, 4, 9, 16, 25]
# Product: 120
# Even numbers: [2, 4]

# %%
# Task 11: Object-Oriented Programming - Creating a Class
# Create a class called 'Rectangle' with attributes 'length' and 'width'.

class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

# Include methods to calculate area and perimeter.
    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

# Test function

rectangle1 = Rectangle(9, 5)
rectangle2 = Rectangle(13, 6)

print("\nTask 11:")
print("Rectangle 1 area:", rectangle1.area())
print("Rectangle 1 perimeter:", rectangle1.perimeter())
print("Rectangle 2 area:", rectangle2.area())
print("Rectangle 2 perimeter:", rectangle2.perimeter())
# Out:
# Task 11:
# Rectangle 1 area: 45
# Rectangle 1 perimeter: 28
# Rectangle 2 area: 78
# Rectangle 2 perimeter: 38

# %%
# Task 12: Pandas Data Analysis
# Using the following DataFrame, perform these tasks:

df_employees = pd.DataFrame({
    'Name': ['John', 'Jane', 'Bob', 'Alice', 'Charlie'],
    'Department': ['IT', 'HR', 'IT', 'Finance', 'HR'],
    'Salary': [55000, 65000, 70000, 60000, 58000]
})

# 1. Find the average salary by department
avg_salary = df_employees.groupby("Department")["Salary"].mean()

# 2. Get the names of employees with salary > 60000
high_salary = df_employees[df_employees["Salary"] > 60000]["Name"]


# 3. Add a new column 'Bonus' which is 10% of salary
df_employees["Bonus"] = df_employees["Salary"] * 0.10

print("\nTask 12: Average salary by department:")
print(avg_salary)

print("\nEmployees with salary > 60000:")
print(high_salary)

print("\nDataFrame with Bonus column:")
print(df_employees)
# Out:
# Task 12: Average salary by department:
# Department
# Finance    60000.0
# HR         61500.0
# IT         62500.0
# Name: Salary, dtype: float64
#
# Employees with salary > 60000:
# 1    Jane
# 2     Bob
# Name: Name, dtype: object
#
# DataFrame with Bonus column:
#       Name Department  Salary   Bonus
# 0     John         IT   55000  5500.0
# 1     Jane         HR   65000  6500.0
# 2      Bob         IT   70000  7000.0
# 3    Alice    Finance   60000  6000.0
# 4  Charlie         HR   58000  5800.0
